# %% [markdown]
# # Welcome to the DCWP mini-coursework.
#
# **Code your solution to tasks 6 to 15; upload the resulting Jupyter notebook on Moodle.**
#
# Present your solution and your comments in the available cell below each task. It is advisable to add new cells, either ``Code`` or ``Markdown`` to better structure and comment your solution to each task.
#
# Additionally, you may create a ``Markdown`` cell at the beginning of the notebook to provide your *Academic declaration* against all forms of plagiarism; the text is online or in the coursework brief.

# %% [markdown]
# #### Data Analytics on the [British Library printed music dataset](https://www.bl.uk/collection-metadata/downloads)

# %% [markdown]
# <img src="https://storage.googleapis.com/kaggle-datasets-images/2805328/4840542/f550bf9fd44bb13162fc7e05549e74db/dataset-cover.jpg?t=2023-01-11-23-24-31" height="200">

# %% [markdown]
# A further data source is available on the [Kaggle repository](https://www.kaggle.com/datasets/peacehegemony/history-of-music-bnb/data)

# %% [markdown]
# Your friend Nora asks you to help with some basic statistics for a British Library dataset called ``bl_printed_music_500.csv.`` This dataset includes 500 records of music books, and is available online in the British Library online sources.
#
# Nora asks you to develop a software in Python to allow basic input-output operations when querying the dataset and extract basic statistics such as:
# * "How many titles are in the dataset?"
# * "How many records are empty?
# * "Can your visualise the results for further examination?"
#
# Nora lacks any coding experience, so she warned you that her descriptions might be a little vague... She comes up with a “todo” list, with some hints as follows.

# %% [markdown]
# **Task 1:** I found this baseline code online that shows you how to open a file and access the first row of the data.
# Try to run it.
# Why does it stop on the first row?

# %%
import csv

FILE = './data/bl_printed_music_500.csv'

with open(FILE , newline='', encoding="utf-8-sig") as csvfile:
    
    reader = csv.DictReader(csvfile)
    
    for row in reader:
        for el in row:
            print(el)        
        break

# It stops immediately because of the break

# %% [markdown]
# **Task 2:**
#
# Nora writes: I worked with this dataset for some time in Excel, but I've been told that you are a Python superstar!
#
# Can you open the csv file in Python and check it out? Since we have a lot of records, print only the first 5 rows. To do this you will need to create a counter, I suppose when the counter is 5, you can just **break** the loop. Try it out, does it work?

# %%
# Provide your solution here
import csv

FILE = './data/bl_printed_music_500.csv'

with open(FILE , newline='', encoding="utf-8-sig") as csvfile:
    
    reader = csv.DictReader(csvfile)
    
    count = 0
    for row in reader:
        print(row)
        count+=1
        if count == 5:       
            break

# %% [markdown]
# > Make sure you open the file in Excel and check the data. By the way, did you spot any issues with the data?
# >
# > If so, let me know!

# %% [markdown]
# <img src='./imgs/bulb.png' width="50" height="50">
#
# > It is always a good idea to open the file in Excel and inspect the dataset, spot problems and use Python to clean the data. By opening the file we can see different issues that we might have to face, for example empty cells or non-English characters.

# %% [markdown]
# Let us examine the dataset.

# %% [markdown]
# ![Excel data.PNG](data:image/png;base64,...)

# %% [markdown]
# > It is a good idea to compare how data look in excel and in python.

# %% [markdown]
# ![Excel data 2.PNG](data:image/png;base64,...)

# %% [markdown]
# **Task 3:** I want to run some basic queries and extract data, can you print the **titles** of the first 5 records?

# %%
# Provide your solution here

import csv

FILE = './data/bl_printed_music_500.csv'

with open(FILE , newline='', encoding = 'utf-8-sig') as csvfile:
    
    reader = csv.DictReader(csvfile)
    
    count = 0
    for row in reader:
        print(row['Title'])
        
        count+=1

        if count == 5:       
            break

# %% [markdown]
# **Task 4:** Study and run the following code. This will help you solve Task 8.
#
# But what about ``hello``?

# %%
phrase = 'Hello World!'

if 'Hello' in phrase:
    print('Yes')

# %% [markdown]
# **Task 5:** Can you print the **Titles** (colunm Title) that include the keyword **Flute**?

# %%
# Provide your solution here

import csv

FILE = './data/bl_printed_music_500.csv'

with open(FILE , newline='', encoding="utf-8-sig") as csvfile:
    
    reader = csv.DictReader(csvfile)
    
    for row in reader:
        if 'Flute' in row['Title']:
            print (row['Title'])

# %% [markdown]
# **Task 6:** Can you count how many titles include the keyword **Piano**?

# %%
# Provide your solution here

# %% [markdown]
# **Task 7:** I want to search for a particular record in the dataset using a “record ID”.
#
# A simple question is the following:
# * *Does record 1706700 exist in my dataset?*
#
# As a reminder, the record ids are numerical values.

# %% [markdown]
# <img src='./imgs/bulb.png' width="50" height="50">
#
# > Remember, each time we import in Python, the data is considered as text, even if the values are numbers.
# >
# > This means that Python translates the number 1706700 as a text (also known as string), in other words 1706700 is represented as "1706700".
# >
# > There are two ways to handle this task, either you need to transform all the numbers to integers, or use the double zeros when you are looking for a record, for example the 1706700 will become 001706700.

# %%
# Provide your solution here

# %% [markdown]
# **Task 8:** Can you create a program for the following?
#
# * The program will ask me to input the record ID
# * Then the program will search in the data and will print True if the record is there, in any other case it will print False.
#
# If possible, create a function. You may name it *searchRecordID* or something like that.
#
# Try your function using the following record id: *1279866*. I suppose this should print True.

# %%
# Provide your solution here

# %% [markdown]
# **Task 9:** Can you count how many **empty** records are in the column **publication date (standardised)** of your dataset?
#
# If you can, create a function. The function argument could be the row to search. Print the results.

# %%
#Provide your solution here

# %% [markdown]
# **Task 10:** Develop a script to search how many times a publication year appears in the column **publication date (standardised)**.
#
# For example
# * **Enter a year to search: 1980**
# * **There are 2 occurencies of year 1980**
#
# As before, I prefer a reusable code! Provide some comments in the code on how to use it!

# %%
# Provide your solution here

# %% [markdown]
# **Task 11:** What is the average of the years for column Publication date (standardised)?

# %%
# Provide your solution here

# %% [markdown]
# **Task 12:** What is the maximum value of the column Publication date (standardised)?

# %%
# Provide your solution here

# %% [markdown]
# **Task 13:** Can you do both? What is the maximum and minimum value of the column Publication date (standardised)? Do not use the max or min built-in functions.

# %%
# Provide your solution here

# %% [markdown]
# **Task 14:** Here's a challenging task for you. Calculate the proportion (in percentage) of a specific record, e.g., London in *Place of publication* in the dataset.
#
# For example, we can say that about 45% of the records were published in London by analysing the *Place of publication* column.
#
# Exclude any missing data from the final calculation and make sure you print the results as a float number with two decimal points.
# You can look online, e.g., on the w3schools, on how to **round** a floating number.
#
# Please note that I would like to use this code to search using different column names. I would prefer if you develop a function to accept two arguments, the user input for searching a place in a *Place of publication* and a column you are looking to search e.g. *Place of publication*.

# %% [markdown]
# <img src='./imgs/mounts.png' width="50" height="50">
#
# > This is a challenging task, so take your time.

# %%
# Provide your solution here

# %% [markdown]
# **Task 15:** Another challenge for you: search for titles using a keyword and count how many times the records (that include this keyword) exist in the dataset.
#
# *	For example, how many times “Sonatas” appear in titles?
#
# *	The result could be something like “There are 25 records that have the keyword “Sonatas” in the dataset”.
#
# To search for a part of a text you might need to use the *in* keyword.

# %%
#Provide your solution here
