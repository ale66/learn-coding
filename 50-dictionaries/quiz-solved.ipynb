# %% [markdown]
# ### Challenge:
#
# Create a dictionary out of the following data:
#
# ![](./imgs/quiz-data.png)

# %% [markdown]
# #### Solution A
#
# Consider a space of columns and describe them with a dictionary of lists:

# %%
my_columnar_data = {'Name':['Andrea', 'Tom'], 
          'Age':[32,35], 
          'City':['London', 'Brighton']
}

# %% [markdown]
# #### Solution B
#
# Consider a space of row, which in turn identify objects we will work with a list of dictionaries:

# %%
my_row_data = [{'Name':'Andrea', 
          'Age':32, 
          'City':'London'},
          {'Name':'Tom', 
          'Age':35, 
          'City':'Brighton'}
]
